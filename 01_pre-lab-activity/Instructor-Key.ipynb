# %% [markdown]
# # Pre Lab Assignment (5 pts)

# %% [markdown]
# :::{admonition} Overview
# **Questions:**
# - What are if/else statements?
# - What are for loops?
#
# **Objectives:**
# - Describe for loops.
# - Plot a summation of gaussian peaks using a for loop.
# :::

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd
# %pip install openpyxl --quiet
import matplotlib.pyplot as plt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Part 1. YouTube Tutorials
#
# Watch the following video to learn about loops

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("-BOBedcjySI",width=640,height=360)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("6iF8Xb7Z3wQ",width=640,height=360)

# %% [markdown]
# :::{danger} ❓ Question 1 (1 pt)
# :icon: false
# What are some initial thoughts you have towards how loops may be useful for data analysis?
# :::{warning} 📝 Student Response
# :icon: false
# To record your response, double click the cell and type your answer after the `>` below!
# > _Type your answer here!_
# ::::::

# %% [markdown]
# ## Part 2. If/Else Statements

# %% [markdown]
# ::::{hint} 🐍 Note: If/Else Statements
# :icon: false
# In programming, sometimes we want our code to **make decisions** based on certain conditions. That's exactly what `if`/`else` statements do: they allow the program to **execute different blocks of code depending on whether a condition is true or false**.
#
# **Basic Structure:**
# ```{code}python
# if condition:
#     # code runs if condition is True
# else:
#     # code runs if condition is False
# ```
#
# - **condition**: A logical expression that evaluates to `True` or `False`.
# - **Indentation**: Python uses indentation to group code blocks. All code inside the `if` or `else` must be indented.
#
#
# :::{note} Example 1: Checking a Number
# ```{code}python
# :linenos:
# :filename:Example 1: Checking a Number
# x = 10
# if x > 5:
#     print("x is greater than 5")
# else:
#     print("x is 5 or smaller")
# ```
# The program checks whether `x > 5`. Since `10 > 5` is `True`, it prints `"x is greater than 5"`. If `x` were `3`, the condition would be `False`, and the `else` block would execute.
#
# :::
#
# :::{note} Example 2: Multiple Conditions with `elif`
# Sometimes we have more than two possibilities. We can use `elif` (short for "else if"):
# ```{code}python
# :linenos:
# temperature = 25
# if temperature > 30:
#     print("It's really hot!")
# elif temperature > 20:
#     print("It's warm.")
# else:
#     print("It's cool.")
# ```
# The program checks conditions in order. Only the first `True` condition will execute. If none are `True`, the `else` block runs.
# :::::::

# %% [markdown]
# :::{warning} ✏️ Exercise (1 pt)
# :icon: false
# Create your own set of `if`/`else` statements to determine if a number is odd or even. Run the code to verify it works **AND** provide an explanation of how it works similar to the explanations given in the above examples.
# :::

# %%
# Create your own if/else statement for odd/number

number=int(input("Enter number "))

if(number%2==0):
  print(number,'is even')
else:
  print(number,'is odd')
# Out:
# Enter number  56
# 56 is even

# %% [markdown]
# ## Part 3. For loops
#
# In Python, a **`for` loop** is used to iterate over a sequence, such as a list, tuple, string, or range, allowing you to execute a block of code repeatedly for each item in the sequence.
#
#
# ### 1. Basic Syntax
# ```python
# for variable in sequence:
#     # code block
# ```
#
# *   variable: A placeholder for each element in the sequence.
# *   sequence: The collection (e.g., list, tuple, string) you want to iterate over.
#
# Example:
# ```python
# fruits = ['apple', 'banana', 'cherry']
# for fruit in fruits:
#     print(fruit)
# ```
#
# ### 2. Range
# The `range()` function generates a sequence of numbers, which is often used in loops.
# ```python
# for i in range(5):  # Generates numbers from 0 to 4
#     print(i)
# ```
#
# > `range(start, stop, step)` allows customization of the range.
#
#
# You can get more detailed with the specification, like looping through different data types (`item in [1, 2, 3]` will give 1, 2, 3 for example).
#
# Multidimensional lists can take advantage of loops within loops, also called **nested loops**
# ```python
# for i in range(3):
#     for j in range(2):
#         print(f"i={i}, j={j}")
# ```

# %% [markdown]
# :::{warning} ✏️ Exercise (1 pt)
# :icon: false
# Copy the for loops into [PythonTutor.com](https://pythontutor.com) and visually see how for loops work. See what each loop does.
#
# :::{warning} 📝 Student Response
# :icon: false
# Provide some commentary, double click the cell and type your answer after the `>` below!
# >_Type your commentary here!_
# ::::::

# %% [markdown]
# :::{hint} 🐍 Note
# :icon: false
# **You will use a for loop combined with your data to generate the computed spectra.**
#
# You will need the `+=` operation, which adds a new value to the existing one and replaces that variable.
#
# - In math terms, `X += 1` is equal to `X = X + 1`.
# - This is useful in recursive algorithms and loops and other processes where you are compounding values or propagating numerical algorithms in time (e.g., time-stepped kinetics and molecular dynamics).
# :::

# %% [markdown]
# #### The += operator
#
# See how the += operator works in a for loop and what the operator does mathematically.

# %%
# s: store sum of all numbers
s = 0
n = int(input("Enter number "))

# run loop n times
# stop: n+1 (because range never include stop number in result)
for i in range(1, n + 1, 1):
    # add current number to sum variable
    s += i
    print(i,s)
print("Sum is: ", s)
# Out:
# Enter number  48
# 1 1
# 2 3
# 3 6
# 4 10
# 5 15
# 6 21
# 7 28
# 8 36
# 9 45
# 10 55
# 11 66
# 12 78
# 13 91
# 14 105
# 15 120
# 16 136
# 17 153
# 18 171
# 19 190
# 20 210
# 21 231
# 22 253
# 23 276
# 24 300
# 25 325
# 26 351
# 27 378
# 28 406
# 29 435
# 30 465
# 31 496
# 32 528
# 33 561
# 34 595
# 35 630
# 36 666
# 37 703
# 38 741
# 39 780
# 40 820
# 41 861
# 42 903
# 43 946
# 44 990
# 45 1035
# 46 1081
# 47 1128
# 48 1176
# Sum is:  1176

# %% [markdown]
# :::{warning} ✏️ Exercise (2 pt)
# :icon: false
# Create a sample spectra by plotting a linear combination of gaussian peaks using the `gaussian_peak` Python function. Plot the result of using widths of 0.25 and 0.5.
# :::

# %%
def gaussian_peak(x, peak_location, amplitude, broadening):
    """
    Generates a Gaussian peak.

    Args:
        x (numpy.ndarray): The x-axis values.
        peak_location (float): The center of the Gaussian peak.
        broadening (float): The standard deviation of the Gaussian peak (controls width).

    Returns:
        numpy.ndarray: The y-values of the Gaussian peak.
    """

    return amplitude * np.exp(-((x - peak_location)**2) / (2 * broadening**2))

# %%
# Define the linear space between 1 and 10 with 10000 points
X=np.linspace(1,10,10000)

# Define peak data
peaks=[1,2.1,5,6.7,8,9]
amps=[3,1,2,5,0.3,2]

# Start of with a- list of zeros.
# You will use the += operation to add the contributions of each computed peak
comp_spec1=np.zeros(len(X))
comp_spec2=np.zeros(len(X))

# Define the for loop
for i in range(len(peaks)):
  comp_spec1+=gaussian_peak(X,peaks[i],amps[i],0.25)
  comp_spec2+=gaussian_peak(X,peaks[i],amps[i],0.50)

# %%
# Plot the computed spectra with the vertical lines representing your computed spectra
plt.plot(X,comp_spec1)
plt.plot(X,comp_spec2)

plt.xlabel('x')
plt.ylabel('y')
plt.show()
